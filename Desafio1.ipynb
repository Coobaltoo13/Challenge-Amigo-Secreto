# %% [markdown]
# <a href="https://colab.research.google.com/github/Coobaltoo13/Challenge-Amigo-Secreto/blob/main/Desafio1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv("tienda_1 .csv")
df2 = pd.read_csv("tienda_2.csv")
df3 = pd.read_csv("tienda_3.csv")
df4 = pd.read_csv("tienda_4.csv")

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !ls
# Out:
#  sample_data  'tienda_1 .csv'   tienda_2.csv   tienda_3.csv   tienda_4.csv

# %%
df
# Out:
#                Producto Categoría del Producto     Precio  Costo de envío  \
# 0     Asistente virtual           Electrónicos   164300.0          6900.0
# 1       Mesa de comedor                Muebles   192300.0          8400.0
# 2         Juego de mesa               Juguetes   209600.0         15900.0
# 3            Microondas      Electrodomésticos   757500.0         41000.0
# 4      Silla de oficina                Muebles   335200.0         20200.0
# ...                 ...                    ...        ...             ...
# 2354          Iphone 15           Electrónicos  1284400.0         66600.0
# 2355          Impresora           Electrónicos   282800.0         15300.0
# 2356      Juego de mesa               Juguetes   122900.0          7200.0
# 2357           Cama box                Muebles   691300.0         35000.0
# 2358         Smartwatch           Electrónicos   195000.0          8600.0
#
#      Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# ...

# %%
df2
# Out:
#               Producto   Categoría del Producto     Precio  Costo de envío  \
# 0     Silla de oficina                  Muebles   283600.0         15300.0
# 1            Pandereta   Instrumentos musicales    76800.0          2300.0
# 2            Cama king                  Muebles   443300.0         23800.0
# 3            Cama king                  Muebles   906200.0         46400.0
# 4     Silla de oficina                  Muebles   397800.0         19400.0
# ...                ...                      ...        ...             ...
# 2354      Set de ollas  Artículos para el hogar   140300.0          8100.0
# 2355  Lavadora de ropa        Electrodomésticos  1220100.0         65200.0
# 2356        Microondas        Electrodomésticos   797900.0         42900.0
# 2357         Iphone 15             Electrónicos  2224300.0        116600.0
# 2358         Bicicleta     Deportes y diversión   551000.0         27500.0
#
# ...

# %%
df3
# Out:
#                      Producto  Categoría del Producto     Precio  \
# 0            Secadora de ropa       Electrodomésticos  1285100.0
# 1               Mesa de noche                 Muebles   290100.0
# 2           Guitarra acústica  Instrumentos musicales   303500.0
# 3           Balón de voleibol    Deportes y diversión    58800.0
# 4                     Armario                 Muebles   521100.0
# ...                       ...                     ...        ...
# 2354  Dashboards con Power BI                  Libros    26700.0
# 2355  Dashboards con Power BI                  Libros    31800.0
# 2356         Silla de oficina                 Muebles   477100.0
# 2357           Mesa de centro                 Muebles   123100.0
# 2358      Modelado predictivo                  Libros    63400.0
#
#       Costo de envío Fecha de Compra         Vendedor Lugar de Compra  \
# 0            66600.0      17/12/2021    Camila Rivera     Santa Marta
# ...

# %%
df4
# Out:
#                  Producto   Categoría del Producto     Precio  Costo de envío  \
# 0            Lavavajillas        Electrodomésticos  1084800.0         56000.0
# 1                Cama box                  Muebles   473800.0         25400.0
# 2     Balón de baloncesto     Deportes y diversión    23700.0             0.0
# 3     Modelado predictivo                   Libros    57700.0          1300.0
# 4             Auriculares             Electrónicos   138900.0          5600.0
# ...                   ...                      ...        ...             ...
# 2353      Mesa de comedor                  Muebles   227700.0         12600.0
# 2354     Silla de oficina                  Muebles   342000.0         18600.0
# 2355         Vaso térmico     Deportes y diversión    36700.0          2400.0
# 2356         Set de ollas  Artículos para el hogar   151800.0          8300.0
# 2357   Cuerda para saltar     Deportes y diversión    11200.0          1300.0
#
# ...

# %%
facturacion_1 = df['Precio'].sum()
facturacion_2 = df2['Precio'].sum()
facturacion_3 = df3['Precio'].sum()
facturacion_4 = df4['Precio'].sum()

print("Tienda 1:", facturacion_1)
print("Tienda 2:", facturacion_2)
print("Tienda 3:", facturacion_3)
print("Tienda 4:", facturacion_4)
# Out:
# Tienda 1: 1150880400.0
# Tienda 2: 1116343500.0
# Tienda 3: 1098019600.0
# Tienda 4: 1038375700.0

# %% [markdown]
# La tienda 1 tiene la mayor facturacion total, facturando 1150880400.0

# %%
df['Categoría del Producto'].value_counts()
# Out:
# Categoría del Producto
# Muebles                    465
# Electrónicos               448
# Juguetes                   324
# Electrodomésticos          312
# Deportes y diversión       284
# Instrumentos musicales     182
# Libros                     173
# Artículos para el hogar    171
# Name: count, dtype: int64

# %% [markdown]
# El producto mas vendido de la tienda 1 es Muebles con 465 unidades vendidas

# %%
df2['Categoría del Producto'].value_counts()
# Out:
# Categoría del Producto
# Muebles                    442
# Electrónicos               422
# Juguetes                   313
# Electrodomésticos          305
# Deportes y diversión       275
# Instrumentos musicales     224
# Libros                     197
# Artículos para el hogar    181
# Name: count, dtype: int64

# %%
El producto mas vendido de la tienda 2 es Muebles con 422 unidades vendidas

# %%
df3['Categoría del Producto'].value_counts()
# Out:
# Categoría del Producto
# Muebles                    499
# Electrónicos               451
# Juguetes                   315
# Electrodomésticos          278
# Deportes y diversión       277
# Libros                     185
# Instrumentos musicales     177
# Artículos para el hogar    177
# Name: count, dtype: int64

# %%
El producto mas vendido de la tienda 3 es Muebles con 499 unidades vendidas

# %%
df4['Categoría del Producto'].value_counts()
# Out:
# Categoría del Producto
# Muebles                    480
# Electrónicos               451
# Juguetes                   338
# Deportes y diversión       277
# Electrodomésticos          254
# Artículos para el hogar    201
# Libros                     187
# Instrumentos musicales     170
# Name: count, dtype: int64

# %% [markdown]
# El producto mas vendido de la tienda 4 es Muebles con 480 unidades vendidas

# %%
df['Producto'].value_counts().head(1)
# Out:
# Producto
# Microondas    60
# Name: count, dtype: int64

# %% [markdown]
# EN la tienda uno, el producto mas vendido es el Microondas con 60 unidades vendidas

# %%
df['Producto'].value_counts().tail(1)
# Out:
# Producto
# Celular ABXY    33
# Name: count, dtype: int64

# %% [markdown]
# En la teinda uno, el producto menos vendido es el Celular ABXY con 33 unidades vendidas

# %%
df2['Producto'].value_counts().head(1)
# Out:
# Producto
# Iniciando en programación    65
# Name: count, dtype: int64

# %% [markdown]
# En la tienda dos el producto mas vendido es Iniciando en Programacion con 65 unidades vendidas

# %%
df2['Producto'].value_counts().tail(1)
# Out:
# Producto
# Juego de mesa    32
# Name: count, dtype: int64

# %% [markdown]
# En la tienda dos el producto menos vendido es Juego de mesa con 32 unidades vendidas

# %%
df3['Producto'].value_counts().head(1)
# Out:
# Producto
# Kit de bancas    57
# Name: count, dtype: int64

# %% [markdown]
# En la tienda 3 el producto mas vendido es el Kit de bancas con 57 unidades vendidas

# %%
df3['Producto'].value_counts().tail(1)
# Out:
# Producto
# Bloques de construcción    35
# Name: count, dtype: int64

# %% [markdown]
# EN la tienda 3 el producto menos vendido es Bloques de construccion con 35 unidades vendidas

# %%
df4['Producto'].value_counts().head(1)
# Out:
# Producto
# Cama box    62
# Name: count, dtype: int64

# %% [markdown]
# En la tienda 4 el producto mas vendido es la Cama box con 62 unidades vendidas

# %%
df4['Producto'].value_counts().tail(1)
# Out:
# Producto
# Guitarra eléctrica    33
# Name: count, dtype: int64

# %% [markdown]
# En la Tienda 4 el producto menos vendido es la Guitarra Electrica con 33 unidades vendidas

# %%
df['Costo de envío'].mean()
# Out:
# np.float64(26018.60958033065)

# %% [markdown]
# A la tienda 1 le cuesta 26018.60 pesos hacer el envio

# %%
df2['Costo de envío'].mean()
# Out:
# np.float64(25216.235693090293)

# %% [markdown]
# A la tienda 2 le cuesta 25216.23 pesos hacer el envio

# %%
df3['Costo de envío'].mean()
# Out:
# np.float64(24805.680373039424)

# %% [markdown]
# A la tienda 3 le cuesta 24805.68 pesos hacer el envio

# %%
df4['Costo de envío'].mean()
# Out:
# np.float64(23459.457167090754)

# %% [markdown]
# A la tienda 4 le cuesta 23459.45 pesos hacer el envio

# %% [markdown]
# La tienda menos rentable es la Tienda 1 por que le cuesta 26018.60 pesos hacer el envio

# %% [markdown]
# Después de analizar la facturación total, las categorías más vendidas, los productos más y menos vendidos y el costo promedio de envío de las cuatro tiendas, se observa que la Tienda 1, a pesar de ser la que presenta la mayor facturación total con $1,150,880,400, también es la que tiene el costo promedio de envío más alto, con un valor de $26,018.60 por envío.
#
# En cuanto a las categorías de productos, se identificó que Muebles es la categoría más vendida en todas las tiendas, lo que indica una alta competencia y poca diferenciación entre ellas. Además, aunque la Tienda 1 cuenta con productos con buenas ventas, como el Microondas, también presenta productos con menor rotación, como el Celular ABXY.
#
# Considerando el elevado costo de envío en comparación con las demás tiendas y la similitud en las categorías más vendidas, se concluye que la Tienda 1 presenta oportunidades de optimización, por lo que se recomienda evaluar su venta para invertir en un nuevo negocio con menores costos operativos y mayor eficiencia logística.
